# %%
# This R environment comes with many helpful analytics packages installed
# It is defined by the kaggle/rstats Docker image: https://github.com/kaggle/docker-rstats
# For example, here's a helpful package to load

library(tidyverse) # metapackage of all tidyverse packages

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

list.files(path = "../input")

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session

# %% [markdown]
# # **CYCLISTIC CAPSTONE COURSE: ¿ HOW CAN WE INCREASE THE NUMBER OF MEMBERSHIPS ?**
#
# ## 1. STATEMENT OF THE BUSINESS TASK.
# <p>The present study is the capsone project of the Google Data Analytics Professional Certificate. For this Case Study, a fictional bike-sharing company called Cyclistic believes that the key for future success relies on increasing the number of members. This company offers 3 types of purchase options: single-ride pass, full-day pass and an annual membership. In order to meet the objective of increasing the membership number, the marketing team asked an answer for these questions:
#
# * How can we better understand how anual members and casuals differ?
# * Why would casual riders buy a membership?
# * How digital media could affect marketing tactics?
# </p>
#
# ## 2. DATA INFO
# <p>The company provided two types of datasets in a csv format, one was purchase information, in these case bike rides, containing id's, duration, starting and finishing location, member or casual and in some cases some information about the user. The other dataset contained information about the docking locations available, including an id for each location, position in coordinates, docking capacity, and inauguration date.
#
# The data available does not include information about prices or any information about the conditions of usage for a member or a casual rider, so at first glance, I can say that I find difficult to answer the second question: Why casuals riders would buy a membership? unless I collect independent data from a similar vehicle-sharing company and analyze the advantages they offer in a membership. The same goes for the third question: How digital media could affect their marketing tactics? I'll have to pull outside data too to evaluate the impact of social media in the marketing strategies.
#
# With the data available by the company, I could analyze how it's growth has happened, how differently do the riders use the bikes and the differences of usage by members and casuals, checking this way how much does the company rely on any one of them.
# <p/>
#
# ## 3. PREPARING THE DATA
# <p>Since the large datasets available, I've decided to use R to prepared and modify the data.
# <p/>

# %%
#---------First let's import the dplyr library and the stations dataset.------------------------------
library(tidyverse)
library(lubridate)
stations2017 = read.csv('../input/stations2017/Divvy_Stations_2017_Q3Q4.csv')

#---------Let's now change the varibles types to the appropiate format and delete one column ---------
stations2017$online_date = mdy_hm(stations2017$online_date)
stations2017$X = NULL

#---------Let's now run a check for duplicates or errors-----------------------------------------------
print(duplicated(stations2017))
print(is.null(stations2017))
stations2017 = stations2017 %>% mutate(year = year(online_date))
stations2017

# %%
#---------Now let's plot how the company grew overtime by plotting the stations in the map------------
library(openintro)
library(ggmap)
library(ggthemes)
library(maps)

chicago_map = get_stamenmap(
        bbox = c(left = -88.3177, bottom =41.4561, right =-86.8208, top =42.1461),
        maptype = "terrain",
        zoom = 10)

ggmap(chicago_map) +
  geom_point(data = stations2017, 
            aes(x = longitude, y = latitude, color = , alpha = 0.5),
            size = 0.5) + 
  theme_map()
